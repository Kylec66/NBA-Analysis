# %% [markdown]
# sources
# https://en.wikipedia.org/wiki/Highest-paid_NBA_players_by_season
# https://www.basketball-reference.com/contracts/salary-cap-history.html
# https://www.basketball-reference.com/leagues/

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np

# %%
#Data File Paths Read in
salary_cap_path = "data/salary_caps.csv"
NBA_index_path = "data/NBA & ABA League Index (basketball-reference).csv"
NBA_payroll_path = "data/NBA_payrolls(1990-2021).csv"
NBA_totals_path = "data/NBA_totals (1990-2021).csv"
NBA_salaries_path = "data/highest salaries per year.csv"
milwaukee_salaries_path = "data/Milwaukee Salaries 2018-19.csv"
newyork_salaries_path = "data/New York Salaries 2018-19.csv"
champions_path = "data/NBA_Champions 1991-2019.csv"

NBA_index_data = pd.read_csv(NBA_index_path)
NBA_totals_data = pd.read_csv(NBA_totals_path)
salary_cap_data = pd.read_csv(salary_cap_path)
NBA_payroll_data = pd.read_csv(NBA_payroll_path)
NBA_highest_salaries = pd.read_csv(NBA_salaries_path)
milwaukee_salaries = pd.read_csv(milwaukee_salaries_path)
newyork_salaries = pd.read_csv(newyork_salaries_path)
NBA_champions = pd.read_csv(champions_path)

# %%
salary_cap_data.head()
# Out:
#       Year  Salary Cap (USD)
# 0  1984-85           3600000
# 1  1985-86           4233000
# 2  1986-87           4945000
# 3  1987-88           6164000
# 4  1988-89           7232000

# %%
NBA_totals_df = NBA_totals_data.rename(columns={"Tm": "Team", "G": "Games","W": "Wins", "L": "Losses", "W/L%": "% Wins and Losses"})
NBA_totals_df
# Out:
#       Season         Team  Games  Wins  Losses  % Wins and Losses
# 0    1990-91      Atlanta     82    43      39              0.524
# 1    1990-91       Boston     82    56      26              0.683
# 2    1990-91     Brooklyn     82    26      56              0.317
# 3    1990-91    Charlotte     82    61      21              0.744
# 4    1990-91      Chicago     82    33      49              0.402
# ..       ...          ...    ...   ...     ...                ...
# 901  2020-21   Sacramento     72    31      41              0.431
# 902  2020-21  San Antonio     72    33      39              0.458
# 903  2020-21      Toronto     72    27      45              0.375
# 904  2020-21         Utah     72    52      20              0.722
# 905  2020-21   Washington     72    34      38              0.472
#
# [906 rows x 6 columns]

# %%
payroll_data_merged_df = pd.merge(salary_cap_data, NBA_payroll_data, how="left", on=["Year", "Year"])
payroll_data_merged_df
# Out:
#         Year  Salary Cap (USD)         Team  Team Payroll (USD)  Current USD
# 0    1984-85           3600000          NaN                 NaN          NaN
# 1    1985-86           4233000          NaN                 NaN          NaN
# 2    1986-87           4945000          NaN                 NaN          NaN
# 3    1987-88           6164000          NaN                 NaN          NaN
# 4    1988-89           7232000          NaN                 NaN          NaN
# ..       ...               ...          ...                 ...          ...
# 907  2020-21         109140000   Sacramento         106847430.0  106847430.0
# 908  2020-21         109140000  San Antonio         129648823.0  129648823.0
# 909  2020-21         109140000      Toronto         129131910.0  129131910.0
# 910  2020-21         109140000         Utah         136131324.0  136131324.0
# 911  2020-21         109140000   Washington         131522450.0  131522450.0
#
# [912 rows x 5 columns]

# %%
payroll_data_merged_df = payroll_data_merged_df.dropna(how='any')

payroll_data_merged_df
# Out:
#         Year  Salary Cap (USD)         Team  Team Payroll (USD)  Current USD
# 6    1990-91          11871000      Atlanta          11761000.0   23340645.0
# 7    1990-91          11871000       Boston          11256000.0   22338430.0
# 8    1990-91          11871000     Brooklyn          11410000.0   22644054.0
# 9    1990-91          11871000    Charlotte          10417000.0   20673368.0
# 10   1990-91          11871000      Chicago          10040000.0   19925184.0
# ..       ...               ...          ...                 ...          ...
# 907  2020-21         109140000   Sacramento         106847430.0  106847430.0
# 908  2020-21         109140000  San Antonio         129648823.0  129648823.0
# 909  2020-21         109140000      Toronto         129131910.0  129131910.0
# 910  2020-21         109140000         Utah         136131324.0  136131324.0
# 911  2020-21         109140000   Washington         131522450.0  131522450.0
#
# [906 rows x 5 columns]

# %%
for row in payroll_data_merged_df.index:
    psc = (payroll_data_merged_df['Team Payroll (USD)'] / payroll_data_merged_df['Salary Cap (USD)']) * 100
      
salary_cap = payroll_data_merged_df['Salary Cap (USD)']
team = payroll_data_merged_df['Team']
season = payroll_data_merged_df['Year']
current_usd = payroll_data_merged_df['Current USD']
team_payroll = payroll_data_merged_df['Team Payroll (USD)']

NBA_payroll_df = pd.DataFrame({"Season": season,
                             "Team": team,
                             "Team Payroll (USD)": team_payroll,
                             "Current Value (USD)": current_usd,
                             "Salary Cap (USD)": salary_cap,
                             "% Salary Cap Used": psc
                            })
NBA_payroll_df = NBA_payroll_df.reset_index(drop=True)

NBA_payroll_df
# Out:
#       Season         Team  Team Payroll (USD)  Current Value (USD)  \
# 0    1990-91      Atlanta          11761000.0           23340645.0
# 1    1990-91       Boston          11256000.0           22338430.0
# 2    1990-91     Brooklyn          11410000.0           22644054.0
# 3    1990-91    Charlotte          10417000.0           20673368.0
# 4    1990-91      Chicago          10040000.0           19925184.0
# ..       ...          ...                 ...                  ...
# 901  2020-21   Sacramento         106847430.0          106847430.0
# 902  2020-21  San Antonio         129648823.0          129648823.0
# 903  2020-21      Toronto         129131910.0          129131910.0
# 904  2020-21         Utah         136131324.0          136131324.0
# 905  2020-21   Washington         131522450.0          131522450.0
#
#      Salary Cap (USD)  % Salary Cap Used
# 0            11871000          99.073372
# 1            11871000          94.819308
# 2            11871000          96.116587
# 3            11871000          87.751664
# 4            11871000          84.575857
# ..                ...                ...
# 901         109140000          97.899423
# 902         109140000         118.791298
# 903         109140000         118.317675
# 904         109140000         124.730918
# 905         109140000         120.508017
#
# [906 rows x 6 columns]

# %%
#remove seasons 2019-20 and 2020-21 due to abnormal season from Covid-19
NBA_summary_df = pd.merge(NBA_payroll_df, NBA_totals_df, how="left", on=["Season", "Team"])
NBA_summary_df = NBA_summary_df.drop(labels=range(846, 906), axis=0)
NBA_summary_df
# Out:
#       Season         Team  Team Payroll (USD)  Current Value (USD)  \
# 0    1990-91      Atlanta          11761000.0           23340645.0
# 1    1990-91       Boston          11256000.0           22338430.0
# 2    1990-91     Brooklyn          11410000.0           22644054.0
# 3    1990-91    Charlotte          10417000.0           20673368.0
# 4    1990-91      Chicago          10040000.0           19925184.0
# ..       ...          ...                 ...                  ...
# 841  2018-19   Sacramento         101466920.0          103805581.0
# 842  2018-19  San Antonio         121588790.0          124391233.0
# 843  2018-19      Toronto         137793831.0          140969781.0
# 844  2018-19         Utah         113826156.0          116449685.0
# 845  2018-19   Washington         123747588.0          126599790.0
#
#      Salary Cap (USD)  % Salary Cap Used  Games  Wins  Losses  \
# 0            11871000          99.073372     82    43      39
# 1            11871000          94.819308     82    56      26
# 2            11871000          96.116587     82    26      56
# 3            11871000          87.751664     82    61      21
# 4            11871000          84.575857     82    33      49
# ..                ...                ...    ...   ...     ...
# 841         101869000          99.605297     82    39      43
# 842         101869000         119.357989     82    48      34
# 843         101869000         135.265715     82    58      24
# 844         101869000         111.737777     82    50      32
# 845         101869000         121.477180     82    32      50
#
#      % Wins and Losses
# 0                0.524
# 1                0.683
# 2                0.317
# 3                0.744
# 4                0.402
# ..                 ...
# 841              0.476
# 842              0.585
# 843              0.707
# 844              0.610
# 845              0.390
#
# [846 rows x 10 columns]

# %%
x_values = NBA_summary_df["% Wins and Losses"]
y_values = NBA_summary_df["% Salary Cap Used"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = rvalue**2
rvaluer = rvalue.round(2)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0.09,215),fontsize=10,color="red")
plt.annotate((f'R-Squared = {rvaluer}'),(0.09,200),fontsize=10,color="blue")
plt.xlabel("% Wins and Losses")
plt.ylabel("% Salary Cap Used")
plt.title(f'NBA Win Loss Ratio Vs Percent Salary Cap Used from 1990-91 to 2018-19')
plt.show()

# %%
team_groupby = NBA_summary_df.groupby(["Team"])
team_means = team_groupby.mean()
team_means.head()
# Out:
#            Team Payroll (USD)  Current Value (USD)  Salary Cap (USD)  \
# Team
# Atlanta          5.034093e+07         6.432707e+07      4.653034e+07
# Boston           5.760672e+07         7.307807e+07      4.653034e+07
# Brooklyn         5.772130e+07         7.350642e+07      4.653034e+07
# Charlotte        4.904401e+07         6.096909e+07      4.686181e+07
# Chicago          5.341999e+07         6.815120e+07      4.653034e+07
#
#            % Salary Cap Used      Games       Wins     Losses  \
# Team
# Atlanta           112.355036  80.344828  39.000000  41.344828
# Boston            126.963006  80.310345  41.758621  38.551724
# Brooklyn          126.327321  80.344828  35.413793  44.931034
# Charlotte         103.107365  80.222222  43.185185  37.037037
# Chicago           119.831988  80.344828  40.482759  39.862069
#
#            % Wins and Losses
# Team
# Atlanta             0.487966
# Boston              0.518586
# Brooklyn            0.439655
# Charlotte           0.535815
# Chicago             0.501724

# %%
team_totals = team_groupby.sum()
team_totals.head()
# Out:
#            Team Payroll (USD)  Current Value (USD)  Salary Cap (USD)  \
# Team
# Atlanta          1.459887e+09         1.865485e+09        1349380000
# Boston           1.670595e+09         2.119264e+09        1349380000
# Brooklyn         1.673918e+09         2.131686e+09        1349380000
# Charlotte        1.324188e+09         1.646165e+09        1265269000
# Chicago          1.549180e+09         1.976385e+09        1349380000
#
#            % Salary Cap Used  Games  Wins  Losses  % Wins and Losses
# Team
# Atlanta          3258.296046   2330  1131    1199             14.151
# Boston           3681.927188   2329  1211    1118             15.039
# Brooklyn         3663.492304   2330  1027    1303             12.750
# Charlotte        2783.898866   2166  1166    1000             14.467
# Chicago          3475.127665   2330  1174    1156             14.550

# %%
for row in team_means.index:
    average_cost_per_win = (team_means['Team Payroll (USD)'] / team_means['Wins'])
average_cost_per_win = average_cost_per_win.sort_values(ascending=True)
average_cost_per_win.plot(kind="bar",title="NBA Average Yearly Cost Per Win From 1990-91 to 2018-19", ylabel="Cost Per Win (Millions)", color="mediumorchid", width=0.5)

plt.show()

# %%
average_yearly_wins = team_means['Wins']                             
average_yearly_wins = average_yearly_wins.sort_values(ascending=True)
average_yearly_wins.plot(kind="bar",title="NBA Average Yearly Wins From 1990-91 to 2018-19", ylabel="Wins", color="darkorange", width=0.5)

plt.show()

# %%
nineteen_season_loc = NBA_summary_df.loc[NBA_summary_df["Season"]=="2018-19", ["Team", "Team Payroll (USD)", "Current Value (USD)", "Salary Cap (USD)", "% Salary Cap Used", "Games", "Wins", "Losses", "% Wins and Losses"]]
nineteen_season_df = nineteen_season.set_index('Team')
nineteen_season_df
# Out:
#                Team Payroll (USD)  Current Value (USD)  Salary Cap (USD)  \
# Team
# Atlanta                79180081.0           81005062.0         101869000
# Boston                125334993.0          128223783.0         101869000
# Brooklyn              118850600.0          121589931.0         101869000
# Charlotte             121427859.0          124226596.0         101869000
# Chicago               112598201.0          115193422.0         101869000
# Cleveland             123255073.0          126095922.0         101869000
# Dallas                 86958881.0           88963153.0         101869000
# Denver                118327016.0          121054282.0         101869000
# Detroit               126557932.0          129474908.0         101869000
# Golden State          146291276.0          149663080.0         101869000
# Houston               126474100.0          129389144.0         101869000
# Indiana               110724804.0          113276848.0         101869000
# LA Clippers           118026816.0          120747162.0         101869000
# LA Lakers             107225482.0          109696872.0         101869000
# Memphis               126107461.0          129014051.0         101869000
# Miami                 153171497.0          156701881.0         101869000
# Milwaukee             130988604.0          134007700.0         101869000
# Minnesota             121962221.0          124773273.0         101869000
# New Orleans           116052756.0          118727603.0         101869000
# New York              123387454.0          126231354.0         101869000
# Oklahoma City         144916427.0          148256541.0         101869000
# Orlando               114394213.0          117030832.0         101869000
# Philadelphia          115127167.0          117780678.0         101869000
# Phoenix               108692835.0          111198041.0         101869000
# Portland              130256600.0          133258826.0         101869000
# Sacramento            101466920.0          103805581.0         101869000
# San Antonio           121588790.0          124391233.0         101869000
# Toronto               137793831.0          140969781.0         101869000
# Utah                  113826156.0          116449685.0         101869000
# Washington            123747588.0          126599790.0         101869000
#
#                % Salary Cap Used  Games  Wins  Losses  % Wins and Losses
# Team
# Atlanta                77.727357     82    29      53              0.354
# Boston                123.035460     82    49      33              0.598
# Brooklyn              116.670037     82    42      40              0.512
# Charlotte             119.200011     82    22      60              0.268
# Chicago               110.532351     82    39      43              0.476
# Cleveland             120.993701     82    19      63              0.232
# Dallas                 85.363438     82    33      49              0.402
# Denver                116.156059     82    54      28              0.659
# Detroit               124.235962     82    41      41              0.500
# Golden State          143.607256     82    57      25              0.695
# Houston               124.153668     82    53      29              0.646
# Indiana               108.693326     82    48      34              0.585
# LA Clippers           115.861367     82    48      34              0.585
# LA Lakers             105.258206     82    37      45              0.451
# Memphis               123.793756     82    33      49              0.402
# Miami                 150.361245     82    39      43              0.476
# Milwaukee             128.585344     82    60      22              0.732
# Minnesota             119.724569     82    36      46              0.439
# New Orleans           113.923525     82    33      49              0.402
# New York              121.123653     82    17      65              0.207
# Oklahoma City         142.257632     82    49      33              0.598
# Orlando               112.295412     82    42      40              0.512
# Philadelphia          113.014918     82    51      31              0.622
# Phoenix               106.698637     82    19      63              0.232
# Portland              127.866770     82    53      29              0.646
# Sacramento             99.605297     82    39      43              0.476
# San Antonio           119.357989     82    48      34              0.585
# Toronto               135.265715     82    58      24              0.707
# Utah                  111.737777     82    50      32              0.610
# Washington            121.477180     82    32      50              0.390

# %%
x_values = nineteen_season_df["% Wins and Losses"]
y_values = nineteen_season_df["% Salary Cap Used"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = rvalue**2
valuer = rvalue.round(2)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0.2,135),fontsize=10,color="red")
plt.annotate((f'R-Squared = {valuer}'),(0.2,140),fontsize=10,color="blue")
plt.xlabel("Percet Wins and Losses")
plt.ylabel("% Salary Cap Used")
plt.title(f'NBA Wins Vs Percent Salary Cap Used (2018-19)')
plt.show()

# %%
for row in nineteen_season_df.index:
    nineteen_cost_per_win = (nineteen_season_df['Team Payroll (USD)'] / nineteen_season_df['Wins'])
nineteen_cost_sorted = nineteen_cost_per_win.sort_values(ascending=True)
nineteen_cost_sorted.plot(kind="bar",title="NBA Cost Per Win Efficiency (2018-19)", ylabel="Cost Per Win (Millions)", color="blue", width=0.5)
plt.show()

# %%
nineteen_season_wins = nineteen_season_df['Wins']                             
nineteen_season_sorted = nineteen_season_wins.sort_values(ascending=False)
nineteen_season_sorted.plot(kind="bar",title="Wins Per Team (2018-19)", ylabel="Wins", color="red", width=0.5)

plt.show()

# %%
x_values = nineteen_season_wins
y_values = nineteen_cost_per_win
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,0)) + "x + " + str(round(intercept,0))
rvalue = rvalue**2
valuer = rvalue.round(2)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40, 7000000),fontsize=10,color="red")
plt.annotate((f'R-Squared = {valuer}'),(40, 6000000),fontsize=10,color="blue")
plt.xlabel("2018-19 Wins")
plt.ylabel("2018-19 Cost Per Win (Millions)")
plt.title(f'2019 Cost Per Win Efficiency Vs Wins')
plt.show()

# %%
#remove salary player with salary of $0
milwaukee_salaries = milwaukee_salaries.drop([20, 2])
milwaukee_salaries
# Out:
#     Rk                 Player    Salary
# 0    1  Giannis Antetokounmpo  24157304
# 1    2            George Hill  19000000
# 3    4        Khris Middleton  13000000
# 4    5         Nikola Mirotić  12500000
# 5    6             Tony Snell  10607143
# 6    7         Ersan İlyasova   7000000
# 7    8        Mirza Teletović   3500000
# 8    9            Jodie Meeks   3454500
# 9   10            Brook Lopez   3382000
# 10  11            D.J. Wilson   2534280
# 11  12       Donte DiVincenzo   2481000
# 12  13          Spencer Hawes   2007058
# 13  14          Larry Sanders   1865547
# 14  15        Pat Connaughton   1641000
# 15  16        Malcolm Brogdon   1544951
# 16  17         Sterling Brown   1378242
# 17  18              Pau Gasol    527467
# 18  19            Tim Frazier    210692
# 19  20          Isaiah Canaan     99290

# %%
newyork_salaries
# Out:
#     Rk             Player      Salary
# 0    1     DeAndre Jordan  22897200.0
# 1    2        Enes Kanter  18622514.0
# 2    3    Wesley Matthews  18622514.0
# 3    4        Joakim Noah  18530000.0
# 4    5       Lance Thomas   7119650.0
# 5    6      Mario Hezonja   6500000.0
# 6    7          Ron Baker   4544400.0
# 7    8    Emmanuel Mudiay   4294480.0
# 8    9    Frank Ntilikina   4155720.0
# 9   10       Dennis Smith   3819960.0
# 10  11         Kevin Knox   3739920.0
# 11  12      Allonzo Trier   3382000.0
# 12  13        Noah Vonleh   1621415.0
# 13  14        Luke Kornet   1619260.0
# 14  15  Mitchell Robinson   1485440.0
# 15  16     Damyean Dotson   1378242.0
# 16  17       John Jenkins    585810.0
# 17  18     Henry Ellenson    427289.0
# 18  19      Billy Garrett     42634.0

# %%
milwaukee_salary_var = np.var(milwaukee_salaries['Salary'],ddof = 0)
milwaukee_salary_std = np.std(milwaukee_salaries['Salary'],ddof = 0)
milwaukee_highest_salary = milwaukee_salaries['Salary'].max()


newyork_salary_var = np.var(newyork_salaries['Salary'],ddof = 0)
newyork_salary_std = np.std(newyork_salaries['Salary'],ddof = 0)
newyork_highest_salary = newyork_salaries['Salary'].max()

salary_difference = milwaukee_highest_salary - newyork_highest_salary

variance_difference = newyork_salary_var - milwaukee_salary_var
std_difference = newyork_salary_std - milwaukee_salary_std
milwaukee_lowest_salary = milwaukee_salaries['Salary'].min()
newyork_lowest_salary = newyork_salaries['Salary'].min()
lowest_salary_difference = milwaukee_lowest_salary - newyork_lowest_salary

print(f"2018-19 Salary Variance of Most Winning Team (Milwaukee) to Least Winning Team (New York)")
print(f"------------------------------------------------------------------")
print(f"Milwaukee Salary Variance:  {milwaukee_salary_var}")
print(f"New York Salary Variance:   {newyork_salary_var}")
print(f"Salary Variance Difference: {variance_difference}")
print(f"------------------------------------------------------------------")
print(f"Milwaukee Salary Standard Deviation:  {milwaukee_salary_std}")
print(f"New York Salary Standard Deviation:   {newyork_salary_std}")
print(f"Salary Standard Deviation Difference: {std_difference}")
print(f"------------------------------------------------------------------")
print(f"Milwaukee's Highest Salary: {milwaukee_highest_salary}")
print(f"New York's Highest Salary:  {newyork_highest_salary}")
print(f"Highest Salary Difference:  {salary_difference}")
print(f"------------------------------------------------------------------")
print(f"Milwaukee's Lowest Salary: {milwaukee_lowest_salary}")
print(f"New York's Lowest Salary:  {newyork_lowest_salary}")
print(f"Lowest Salary Difference:  {lowest_salary_difference}")
# Out:
# 2018-19 Salary Variance of Most Winning Team (Milwaukee) to Least Winning Team (New York)
# ------------------------------------------------------------------
# Milwaukee Salary Variance:  44587472783785.56
# New York Salary Variance:   50481234652518.56
# Salary Variance Difference: 5893761868733.0
# ------------------------------------------------------------------
# Milwaukee Salary Standard Deviation:  6677385.175634664
# New York Salary Standard Deviation:   7105014.753856502
# Salary Standard Deviation Difference: 427629.578221838
# ------------------------------------------------------------------
# Milwaukee's Highest Salary: 24157304
# New York's Highest Salary:  22897200.0
# Highest Salary Difference:  1260104.0
# ------------------------------------------------------------------
# Milwaukee's Lowest Salary: 99290
# New York's Lowest Salary:  42634.0
# Lowest Salary Difference:  56656.0

# %%
team_payroll_offset = NBA_summary_df.loc[NBA_summary_df["Season"] != "2016-17", ["Season", "Team", "Team Payroll (USD)", "% Salary Cap Used"]]
team_payroll_offset = team_payroll_offset.loc[NBA_summary_df["Season"] != "2017-18", ["Season", "Team", "Team Payroll (USD)", "% Salary Cap Used"]]
team_payroll_offset = team_payroll_offset.loc[NBA_summary_df["Season"] != "2018-19", ["Season", "Team", "Team Payroll (USD)", "% Salary Cap Used"]]
team_wins_offset = NBA_summary_df.loc[NBA_summary_df["Season"] != "1990-91", ["Season", "Team", "Wins"]]
team_wins_offset = team_wins_offset.loc[NBA_summary_df["Season"] != "1991-92", ["Season", "Team", "Wins"]]
team_wins_offset = team_wins_offset.loc[NBA_summary_df["Season"] != "1992-93", ["Season", "Team", "Wins"]]

team_payroll_offset
# Out:
#       Season         Team  Team Payroll (USD)  % Salary Cap Used
# 0    1990-91      Atlanta          11761000.0          99.073372
# 1    1990-91       Boston          11256000.0          94.819308
# 2    1990-91     Brooklyn          11410000.0          96.116587
# 3    1990-91    Charlotte          10417000.0          87.751664
# 4    1990-91      Chicago          10040000.0          84.575857
# ..       ...          ...                 ...                ...
# 751  2015-16   Sacramento          70610560.0         100.872229
# 752  2015-16  San Antonio          87832839.0         125.475484
# 753  2015-16      Toronto          71591189.0         102.273127
# 754  2015-16         Utah          63608425.0          90.869179
# 755  2015-16   Washington          85055155.0         121.507364
#
# [756 rows x 4 columns]

# %%
#x_values = team_payroll_offset['% Salary Cap Used']
#y_values = team_wins_offset['Wins']
#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#regress_values = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,0)) + "x + " + str(round(intercept,0))
#rvalue = rvalue**2
#valuer = rvalue.round(2)
#plt.scatter(x_values,y_values)
#plt.plot(x_values,regress_values,"r-")
#plt.annotate(line_eq,(40, 7000000),fontsize=10,color="red")
#plt.annotate((f'R-Squared = {valuer}'),(40, 6000000),fontsize=10,color="blue")
#plt.xlabel("2018-19 Wins")
#plt.ylabel("2018-19 Cost Per Win (Millions)")
#plt.title(f'2019 Cost Per Win Efficiency Vs Wins')
#plt.show()

# %%
NBA_highest_salaries
# Out:
#      Season            Player          Team    Salary
# 0   1984-85     Magic Johnson     LA Lakers   2500000
# 1   1985-86     Magic Johnson     LA Lakers   2500000
# 2   1986-87     Magic Johnson     LA Lakers   2500000
# 3   1987-88     Patrick Ewing      New York   2750000
# 4   1988-89     Patrick Ewing      New York   3250000
# 5   1989-90     Patrick Ewing      New York   3750000
# 6   1990-91     Patrick Ewing      New York   4250000
# 7   1991-92        Larry Bird        Boston   7070000
# 8   1992-93    David Robinson   San Antonio   5720000
# 9   1993-94    David Robinson   San Antonio   5740000
# 10  1994-95     Magic Johnson     LA Lakers  14660000
# 11  1995-96     Patrick Ewing      New York  18724000
# 12  1996-97    Michael Jordan       Chicago  30140000
# 13  1997-98    Michael Jordan       Chicago  33140000
# 14  1998-99     Patrick Ewing      New York  18500000
# 15  1999-00  Shaquille O'Neal   Los Angeles  17142000
# 16  2000-01     Kevin Garnett     Minnesota  19600000
# 17  2001-02     Kevin Garnett     Minnesota  22400000
# 18  2002-03     Kevin Garnett     Minnesota  25200000
# 19  2003-04     Kevin Garnett     Minnesota  28000000
# 20  2004-05  Shaquille O'Neal         Miami  27696430
# 21  2005-06  Shaquille O'Neal         Miami  20000000
# 22  2006-07     Kevin Garnett     Minnesota  21000000
# 23  2007-08     Kevin Garnett        Boston  23751934
# 24  2008-09     Kevin Garnett        Boston  24751934
# 25  2009�10       Kobe Bryant     LA Lakers  23034375
# 26  2010�11       Kobe Bryant     LA Lakers  24806250
# 27  2011-12       Kobe Bryant     LA Lakers  25244493
# 28  2012-13       Kobe Bryant     LA Lakers  30453805
# 29  2013-14       Kobe Bryant     LA Lakers  30453805
# 30  2014-15       Kobe Bryant     LA Lakers  23500000
# 31  2015-16       Kobe Bryant     LA Lakers  25000000
# 32  2016-17      LeBron James     Cleveland  30963450
# 33  2017-18     Stephen Curry  Golden State  34682550
# 34  2018-19     Stephen Curry  Golden State  37457154
# 35  2019�20     Stephen Curry  Golden State  40231758
# 36  2020-21     Stephen Curry  Golden State  43006362

# %%
highest_salaries_champions = pd.merge(NBA_highest_salaries, NBA_champions, how="left", on=["Season", "Season"])
highest_salaries_champions = highest_salaries_champions.dropna(how='any')
highest_salaries_champions = highest_salaries_champions.rename(columns={"Player": "Highest Paid Player", "Team": "Team of Player"})
highest_salaries_champions = highest_salaries_champions.set_index('Season')
highest_salaries_champions
# Out:
#         Highest Paid Player Team of Player    Salary      Champion  \
# Season
# 1990-91       Patrick Ewing       New York   4250000       Chicago
# 1991-92          Larry Bird         Boston   7070000       Chicago
# 1992-93      David Robinson    San Antonio   5720000       Chicago
# 1993-94      David Robinson    San Antonio   5740000       Houston
# 1994-95       Magic Johnson      LA Lakers  14660000       Houston
# 1995-96       Patrick Ewing       New York  18724000       Chicago
# 1996-97      Michael Jordan        Chicago  30140000       Chicago
# 1997-98      Michael Jordan        Chicago  33140000       Chicago
# 1998-99       Patrick Ewing       New York  18500000   San Antonio
# 1999-00    Shaquille O'Neal      LA Lakers  17142000     LA Lakers
# 2000-01       Kevin Garnett      Minnesota  19600000     LA Lakers
# 2001-02       Kevin Garnett      Minnesota  22400000     LA Lakers
# 2002-03       Kevin Garnett      Minnesota  25200000   San Antonio
# 2003-04       Kevin Garnett      Minnesota  28000000       Detroit
# 2004-05    Shaquille O'Neal          Miami  27696430   San Antonio
# 2005-06    Shaquille O'Neal          Miami  20000000         Miami
# 2006-07       Kevin Garnett      Minnesota  21000000   San Antonio
# 2007-08       Kevin Garnett         Boston  23751934        Boston
# 2008-09       Kevin Garnett         Boston  24751934   Los Angeles
# 2011-12         Kobe Bryant      LA Lakers  25244493         Miami
# 2012-13         Kobe Bryant      LA Lakers  30453805         Miami
# 2013-14         Kobe Bryant      LA Lakers  30453805   San Antonio
# 2014-15         Kobe Bryant      LA Lakers  23500000  Golden State
# 2015-16         Kobe Bryant      LA Lakers  25000000     Cleveland
# 2016-17        LeBron James      Cleveland  30963450  Golden State
# 2017-18       Stephen Curry   Golden State  34682550  Golden State
# 2018-19       Stephen Curry   Golden State  37457154       Toronto
#
#                       Runner-Up
# Season
# 1990-91      Los Angeles Lakers
# 1991-92  Portland Trail Blazers
# 1992-93            Phoenix Suns
# 1993-94         New York Knicks
# 1994-95           Orlando Magic
# 1995-96     Seattle SuperSonics
# 1996-97               Utah Jazz
# 1997-98               Utah Jazz
# 1998-99         New York Knicks
# 1999-00          Indiana Pacers
# 2000-01      Philadelphia 76ers
# 2001-02         New Jersey Nets
# 2002-03         New Jersey Nets
# 2003-04      Los Angeles Lakers
# 2004-05         Detroit Pistons
# 2005-06        Dallas Mavericks
# 2006-07     Cleveland Cavaliers
# 2007-08      Los Angeles Lakers
# 2008-09           Orlando Magic
# 2011-12   Oklahoma City Thunder
# 2012-13       San Antonio Spurs
# 2013-14                   Miami
# 2014-15     Cleveland Cavaliers
# 2015-16   Golden State Warriors
# 2016-17     Cleveland Cavaliers
# 2017-18     Cleveland Cavaliers
# 2018-19   Golden State Warriors

# %%
#highest_salary_count = highest_salaries_champions.loc[highest_salaries_champions["Team of Player"] == highest_salaries_champions["Champion"], ["Higest Paid Player", "Team of Player", "Salary", "Champion"]]
chicago = highest_salaries_champions.loc[(highest_salaries_champions["Team of Player"] == "Chicago") & (highest_salaries_champions["Champion"] == "Chicago"), :]

houston = highest_salaries_champions.loc[(highest_salaries_champions["Team of Player"] == "Houston") & (highest_salaries_champions["Champion"] == "Houston"), :]
san_antonio = highest_salaries_champions.loc[(highest_salaries_champions["Team of Player"] == "San Antonio") & (highest_salaries_champions["Champion"] == "San Antonio"), :]
lakers = highest_salaries_champions.loc[(highest_salaries_champions["Team of Player"] == "Lakers") & (highest_salaries_champions["Champion"] == "Lakers"), :]
detroit = highest_salaries_champions.loc[(highest_salaries_champions["Team of Player"] == "Detroit") & (highest_salaries_champions["Champion"] == "Detroit"), :]
miami = lakers = highest_salaries_champions.loc[(highest_salaries_champions["Team of Player"] == "Miami") & (highest_salaries_champions["Champion"] == "Miami"), :]
golden_state = lakers = highest_salaries_champions.loc[(highest_salaries_champions["Team of Player"] == "Golden State") & (highest_salaries_champions["Champion"] == "Golden State"), :]
cleveland = lakers = highest_salaries_champions.loc[(highest_salaries_champions["Team of Player"] == "cleveland") & (highest_salaries_champions["Champion"] == "cleveland"), :]

chicago_len = len(chicago)
san_antonio_len = len(san_antonio)
lakers_len = len(lakers)
detroit_len = len(detroit)
miami_len = len(miami)
golden_state_len = len(golden_state)
cleveland_len = len(cleveland)

total_champions_high = chicago_len + san_antonio_len + lakers_len + detroit_len + golden_state_len + cleveland_len + miami_len
total_champions_high
total_len = len(highest_salaries_champions)
total_len
# Out:
# 27

# %%
labels = ["% Champions With Highest Paid Player", "% Champions Without Highest Paid Player"]

# The values of each section of the pie chart
sizes = [total_champions_high, total_len]

# The colors of each section of the pie chart
colors = ["red", "orange"]

plt.pie(sizes, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title(f'Percentage of Teams That Won a NBA Championship With the Highest Paid Player (1991 to 2019)')
plt.show()
